# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")

# %%
df.head(10)
# Out:
#                                    Population  Violent  Property  Murder  \
# Year
# 1970-01-01 00:00:00.000001960  40954135602600   288460   3095700    9110
# 1970-01-01 00:00:00.000001961  40954135602600   289390   3198600    8740
# 1970-01-01 00:00:00.000001962  40954135602600   301510   3450700    8530
# 1970-01-01 00:00:00.000001963  40954135602600   316970   3792500    8640
# 1970-01-01 00:00:00.000001964  40954135602600   364220   4200400    9360
# 1970-01-01 00:00:00.000001965  40954135602600   387390   4352000    9960
# 1970-01-01 00:00:00.000001966  40954135602600   430180   4793300   11040
# 1970-01-01 00:00:00.000001967  40954135602600   499930   5403500   12240
# 1970-01-01 00:00:00.000001968  40954135602600   595010   6125200   13800
# 1970-01-01 00:00:00.000001969  40954135602600   661870   6749000   14760
#
#                                Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# 1970-01-01 00:00:00.000001960          17190   107840              154320
# ...

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
Type_of_columns=df.dtypes
print(Type_of_columns)
# Out:
# Year                  datetime64[ns]
# Population                     int64
# Total                          int64
# Violent                        int64
# Property                       int64
# Murder                         int64
# Forcible_Rape                  int64
# Robbery                        int64
# Aggravated_assault             int64
# Burglary                       int64
# Larceny_Theft                  int64
# Vehicle_Theft                  int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
df['Year']=df['Year'].astype({'Year':'datetime64[ns]'})
#df['Year']=df['Year'].apply(np.datetime64)

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
df=df.set_index('Year',drop=True)
df.head()
# Out:
#                                Population    Total  Violent  Property  Murder  \
# Year
# 1970-01-01 00:00:00.000001960   179323175  3384200   288460   3095700    9110
# 1970-01-01 00:00:00.000001961   182992000  3488000   289390   3198600    8740
# 1970-01-01 00:00:00.000001962   185771000  3752200   301510   3450700    8530
# 1970-01-01 00:00:00.000001963   188483000  4109500   316970   3792500    8640
# 1970-01-01 00:00:00.000001964   191141000  4564600   364220   4200400    9360
#
#                                Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# 1970-01-01 00:00:00.000001960          17190   107840              154320
# 1970-01-01 00:00:00.000001961          17220   106670              156760
# 1970-01-01 00:00:00.000001962          17550   110860              164570
# 1970-01-01 00:00:00.000001963          17650   116470              174210
# 1970-01-01 00:00:00.000001964          21420   130390              203050
#
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
#df.drop(['Total'], axis = 1)
del df['Total']

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
df_decades=df.resample('10AS').sum()
population_max=df.Population.resample('10AS').sum().max()
df['Population']=population_max
df
# Out:
#                                        Population  Violent  Property  Murder  \
# Year
# 1970-01-01 00:00:00.000001960  123886260197865184   288460   3095700    9110
# 1970-01-01 00:00:00.000001961  123886260197865184   289390   3198600    8740
# 1970-01-01 00:00:00.000001962  123886260197865184   301510   3450700    8530
# 1970-01-01 00:00:00.000001963  123886260197865184   316970   3792500    8640
# 1970-01-01 00:00:00.000001964  123886260197865184   364220   4200400    9360
# 1970-01-01 00:00:00.000001965  123886260197865184   387390   4352000    9960
# 1970-01-01 00:00:00.000001966  123886260197865184   430180   4793300   11040
# 1970-01-01 00:00:00.000001967  123886260197865184   499930   5403500   12240
# 1970-01-01 00:00:00.000001968  123886260197865184   595010   6125200   13800
# 1970-01-01 00:00:00.000001969  123886260197865184   661870   6749000   14760
# 1970-01-01 00:00:00.000001970  123886260197865184   738820   7359200   16000
# ...

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
df.idxmax(0)
# Out:
# Population           1970-01-01 00:00:00.000001960
# Violent              1970-01-01 00:00:00.000001992
# Property             1970-01-01 00:00:00.000001991
# Murder               1970-01-01 00:00:00.000001991
# Forcible_Rape        1970-01-01 00:00:00.000001992
# Robbery              1970-01-01 00:00:00.000001991
# Aggravated_assault   1970-01-01 00:00:00.000001993
# Burglary             1970-01-01 00:00:00.000001980
# Larceny_Theft        1970-01-01 00:00:00.000001991
# Vehicle_Theft        1970-01-01 00:00:00.000001991
# dtype: datetime64[ns]
